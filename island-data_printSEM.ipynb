# %% [markdown]
# ## Long Island Hedonic Analysis - Draft
# ### Visualizing the data
# #### created by Doug Patton
# <br>
# If you run the notebook with matplotlib widgets turned on (and installed), you can rotate and zoom in on the 3d plots.

# %%
import island

# %%
import numpy as np
import pandas as pd

# %%
#from importlib import reload  
#reload(island)

# %%
# %matplotlib inline
#may be necessary to display plots inline on some systems
#%pylab #interactive graphs in external window
#%matplotlib widget #makes graphs interactive inline

# %%
idata_obj=island.IslandData()

# %%
#idata_obj.getDataFromCSV() # run once

# %%
#idata_obj.doCSVToDict() # run once

# %%
idata_obj.makeTimeListArrayList()

# %%
#create new real version for each dollar variable using the CPI
baseyear=2015
idata_obj.addRealByCPI(to_year=baseyear)

# %%
idata_obj.arrayListToPandasDF()

# %%
#idata_obj.justMakeWeights()

# %%
#resultslistlist=idata_obj.runSpatialModel()

# %%
#idata_obj.saveSpatialModelResults([],load=1) #created in non anaconda python3.6 env with pysal 2.2
# Out:
# [[{'modeldict': {'combine_pre_post': 0,
#     'period': 0,
#     'modeltype': 'SEM',
#     'klist': 5,
#     'xvars': ['secchi',
#      'bayfront',
#      'wateraccess',
#      'wqbayfront',
#      'wqwateraccess',
#      'totalbathroomsedited',
#      'totallivingarea',
#      'parcel_area',
#      'distance_park',
#      'distance_nyc',
#      'distance_golf',
#      'shorelinedistancedv3_1000',
#      'shorelinedistancedv1000_2000',
#      'shorelinedistancedv2000_3000',
#      'wqshorelinedistancedv3_1000',
#      'wqshorelinedistancedv1000_2000',
#      'wqshorelinedistancedv2000_3000',
#      'education',
#      'income_real-2015',
#      'povertylevel',
#      'pct_white',
#      'dv_2002',
#      'dv_2003',
#      'dv_2004',
#      'dv_2005',
#      'dv_2006',
#      'dv_2007',
#      'dv_2008',
#      'dv_2009',
#      'dv_2010',
#      'dv_2011',
#      'dv_2012',
#      'dv_2013',
#      'dv_2014',
#      'dv_2015'],
#     'yvar': 'saleprice_real-2015',
#     'transform': {'ln_wq': 1, 'ln_y': 1},
#     'wt_type': 'NN',
#     'NNscope': 'year',
#     'distmat': 1},
#    'results': <spreg.ml_error.ML_Error at 0x7f8056589438>},
#   {'modeldict': {'combine_pre_post': 0,
#     'period': 0,
#     'modeltype': 'SEM',
#     'klist': 10,
#     'xvars': ['secchi',
#      'bayfront',
#      'wateraccess',
#      'wqbayfront',
#      'wqwateraccess',
#      'totalbathroomsedited',
#      'totallivingarea',
#      'parcel_area',
#      'distance_park',
#      'distance_nyc',
#      'distance_golf',
#      'shorelinedistancedv3_1000',
#      'shorelinedistancedv1000_2000',
#      'shorelinedistancedv2000_3000',
#      'wqshorelinedistancedv3_1000',
#      'wqshorelinedistancedv1000_2000',
#      'wqshorelinedistancedv2000_3000',
#      'education',
#      'income_real-2015',
#      'povertylevel',
#      'pct_white',
#      'dv_2002',
#      'dv_2003',
#      'dv_2004',
#      'dv_2005',
#      'dv_2006',
#      'dv_2007',
#      'dv_2008',
#      'dv_2009',
#      'dv_2010',
#      'dv_2011',
#      'dv_2012',
#      'dv_2013',
#      'dv_2014',
#      'dv_2015'],
#     'yvar': 'saleprice_real-2015',
#     'transform': {'ln_wq': 1, 'ln_y': 1},
#     'wt_type': 'NN',
#     'NNscope': 'year',
#     'distmat': 1},
#    'results': <spreg.ml_error.ML_Error at 0x7f80565899e8>},
#   {'modeldict': {'combine_pre_post': 0,
#     'period': 0,
#     'modeltype': 'SEM',
#     'klist': 15,
#     'xvars': ['secchi',
#      'bayfront',
#      'wateraccess',
#      'wqbayfront',
#      'wqwateraccess',
#      'totalbathroomsedited',
#      'totallivingarea',
#      'parcel_area',
#      'distance_park',
#      'distance_nyc',
#      'distance_golf',
#      'shorelinedistancedv3_1000',
#      'shorelinedistancedv1000_2000',
#      'shorelinedistancedv2000_3000',
#      'wqshorelinedistancedv3_1000',
#      'wqshorelinedistancedv1000_2000',
#      'wqshorelinedistancedv2000_3000',
#      'education',
#      'income_real-2015',
#      'povertylevel',
#      'pct_white',
#      'dv_2002',
#      'dv_2003',
#      'dv_2004',
#      'dv_2005',
#      'dv_2006',
#      'dv_2007',
#      'dv_2008',
#      'dv_2009',
#      'dv_2010',
#      'dv_2011',
#      'dv_2012',
#      'dv_2013',
#      'dv_2014',
#      'dv_2015'],
#     'yvar': 'saleprice_real-2015',
#     'transform': {'ln_wq': 1, 'ln_y': 1},
#     'wt_type': 'NN',
#     'NNscope': 'year',
#     'distmat': 1},
#    'results': <spreg.ml_error.ML_Error at 0x7f8056589e10>},
#   {'modeldict': {'combine_pre_post': 0,
#     'period': 0,
#     'modeltype': 'SEM',
#     'klist': 20,
#     'xvars': ['secchi',
#      'bayfront',
#      'wateraccess',
#      'wqbayfront',
#      'wqwateraccess',
#      'totalbathroomsedited',
#      'totallivingarea',
#      'parcel_area',
#      'distance_park',
#      'distance_nyc',
#      'distance_golf',
#      'shorelinedistancedv3_1000',
#      'shorelinedistancedv1000_2000',
#      'shorelinedistancedv2000_3000',
#      'wqshorelinedistancedv3_1000',
#      'wqshorelinedistancedv1000_2000',
#      'wqshorelinedistancedv2000_3000',
#      'education',
#      'income_real-2015',
#      'povertylevel',
#      'pct_white',
#      'dv_2002',
#      'dv_2003',
#      'dv_2004',
#      'dv_2005',
#      'dv_2006',
#      'dv_2007',
#      'dv_2008',
#      'dv_2009',
#      'dv_2010',
#      'dv_2011',
#      'dv_2012',
#      'dv_2013',
#      'dv_2014',
#      'dv_2015'],
#     'yvar': 'saleprice_real-2015',
#     'transform': {'ln_wq': 1, 'ln_y': 1},
#     'wt_type': 'NN',
#     'NNscope': 'year',
#     'distmat': 1},
#    'results': <spreg.ml_error.ML_Error at 0x7f8056587278>},
#   {'modeldict': {'combine_pre_post': 0,
#     'period': 0,
#     'modeltype': 'SEM',
#     'klist': 25,
#     'xvars': ['secchi',
#      'bayfront',
#      'wateraccess',
#      'wqbayfront',
#      'wqwateraccess',
#      'totalbathroomsedited',
#      'totallivingarea',
#      'parcel_area',
#      'distance_park',
#      'distance_nyc',
#      'distance_golf',
#      'shorelinedistancedv3_1000',
#      'shorelinedistancedv1000_2000',
#      'shorelinedistancedv2000_3000',
#      'wqshorelinedistancedv3_1000',
#      'wqshorelinedistancedv1000_2000',
#      'wqshorelinedistancedv2000_3000',
#      'education',
#      'income_real-2015',
#      'povertylevel',
#      'pct_white',
#      'dv_2002',
#      'dv_2003',
#      'dv_2004',
#      'dv_2005',
#      'dv_2006',
#      'dv_2007',
#      'dv_2008',
#      'dv_2009',
#      'dv_2010',
#      'dv_2011',
#      'dv_2012',
#      'dv_2013',
#      'dv_2014',
#      'dv_2015'],
#     'yvar': 'saleprice_real-2015',
#     'transform': {'ln_wq': 1, 'ln_y': 1},
#     'wt_type': 'NN',
#     'NNscope': 'year',
#     'distmat': 1},
#    'results': <spreg.ml_error.ML_Error at 0x7f80565876a0>},
#   {'modeldict': {'combine_pre_post': 0,
#     'period': 0,
#     'modeltype': 'SEM',
#     'klist': 50,
#     'xvars': ['secchi',
#      'bayfront',
#      'wateraccess',
#      'wqbayfront',
#      'wqwateraccess',
#      'totalbathroomsedited',
#      'totallivingarea',
#      'parcel_area',
#      'distance_park',
#      'distance_nyc',
#      'distance_golf',
#      'shorelinedistancedv3_1000',
#      'shorelinedistancedv1000_2000',
#      'shorelinedistancedv2000_3000',
#      'wqshorelinedistancedv3_1000',
#      'wqshorelinedistancedv1000_2000',
#      'wqshorelinedistancedv2000_3000',
#      'education',
#      'income_real-2015',
#      'povertylevel',
#      'pct_white',
#      'dv_2002',
#      'dv_2003',
#      'dv_2004',
#      'dv_2005',
#      'dv_2006',
#      'dv_2007',
#      'dv_2008',
#      'dv_2009',
#      'dv_2010',
#      'dv_2011',
#      'dv_2012',
#      'dv_2013',
#      'dv_2014',
#      'dv_2015'],
#     'yvar': 'saleprice_real-2015',
#     'transform': {'ln_wq': 1, 'ln_y': 1},
#     'wt_type': 'NN',
#     'NNscope': 'year',
#     'distmat': 1},
#    'results': <spreg.ml_error.ML_Error at 0x7f8056587ac8>},
#   {'modeldict': {'combine_pre_post': 0,
#     'period': 0,
#     'modeltype': 'SEM',
#     'klist': 100,
#     'xvars': ['secchi',
#      'bayfront',
#      'wateraccess',
#      'wqbayfront',
#      'wqwateraccess',
#      'totalbathroomsedited',
#      'totallivingarea',
#      'parcel_area',
#      'distance_park',
#      'distance_nyc',
#      'distance_golf',
#      'shorelinedistancedv3_1000',
#      'shorelinedistancedv1000_2000',
#      'shorelinedistancedv2000_3000',
#      'wqshorelinedistancedv3_1000',
#      'wqshorelinedistancedv1000_2000',
#      'wqshorelinedistancedv2000_3000',
#      'education',
#      'income_real-2015',
#      'povertylevel',
#      'pct_white',
#      'dv_2002',
#      'dv_2003',
#      'dv_2004',
#      'dv_2005',
#      'dv_2006',
#      'dv_2007',
#      'dv_2008',
#      'dv_2009',
#      'dv_2010',
#      'dv_2011',
#      'dv_2012',
#      'dv_2013',
#      'dv_2014',
#      'dv_2015'],
#     'yvar': 'saleprice_real-2015',
#     'transform': {'ln_wq': 1, 'ln_y': 1},
#     'wt_type': 'NN',
#     'NNscope': 'year',
#     'distmat': 1},
#    'results': <spreg.ml_error.ML_Error at 0x7f8056587ef0>},
#   {'modeldict': {'combine_pre_post': 0,
#     'period': 1,
#     'modeltype': 'SEM',
#     'klist': 5,
#     'xvars': ['secchi',
#      'bayfront',
#      'wateraccess',
#      'wqbayfront',
#      'wqwateraccess',
#      'totalbathroomsedited',
#      'totallivingarea',
#      'parcel_area',
#      'distance_park',
#      'distance_nyc',
#      'distance_golf',
#      'shorelinedistancedv3_1000',
#      'shorelinedistancedv1000_2000',
#      'shorelinedistancedv2000_3000',
#      'wqshorelinedistancedv3_1000',
#      'wqshorelinedistancedv1000_2000',
#      'wqshorelinedistancedv2000_3000',
#      'education',
#      'income_real-2015',
#      'povertylevel',
#      'pct_white',
#      'dv_2002',
#      'dv_2003',
#      'dv_2004',
#      'dv_2005',
#      'dv_2006',
#      'dv_2007',
#      'dv_2008',
#      'dv_2009',
#      'dv_2010',
#      'dv_2011',
#      'dv_2012',
#      'dv_2013',
#      'dv_2014',
#      'dv_2015'],
#     'yvar': 'saleprice_real-2015',
#     'transform': {'ln_wq': 1, 'ln_y': 1},
#     'wt_type': 'NN',
#     'NNscope': 'year',
#     'distmat': 1},
#    'results': <spreg.ml_error.ML_Error at 0x7f8056598358>},
#   {'modeldict': {'combine_pre_post': 0,
#     'period': 1,
#     'modeltype': 'SEM',
#     'klist': 10,
#     'xvars': ['secchi',
#      'bayfront',
#      'wateraccess',
#      'wqbayfront',
#      'wqwateraccess',
#      'totalbathroomsedited',
#      'totallivingarea',
#      'parcel_area',
#      'distance_park',
#      'distance_nyc',
#      'distance_golf',
#      'shorelinedistancedv3_1000',
#      'shorelinedistancedv1000_2000',
#      'shorelinedistancedv2000_3000',
#      'wqshorelinedistancedv3_1000',
#      'wqshorelinedistancedv1000_2000',
#      'wqshorelinedistancedv2000_3000',
#      'education',
#      'income_real-2015',
#      'povertylevel',
#      'pct_white',
#      'dv_2002',
#      'dv_2003',
#      'dv_2004',
#      'dv_2005',
#      'dv_2006',
#      'dv_2007',
#      'dv_2008',
#      'dv_2009',
#      'dv_2010',
#      'dv_2011',
#      'dv_2012',
#      'dv_2013',
#      'dv_2014',
#      'dv_2015'],
#     'yvar': 'saleprice_real-2015',
#     'transform': {'ln_wq': 1, 'ln_y': 1},
#     'wt_type': 'NN',
#     'NNscope': 'year',
#     'distmat': 1},
#    'results': <spreg.ml_error.ML_Error at 0x7f80565985f8>},
#   {'modeldict': {'combine_pre_post': 0,
#     'period': 1,
#     'modeltype': 'SEM',
#     'klist': 15,
#     'xvars': ['secchi',
#      'bayfront',
#      'wateraccess',
#      'wqbayfront',
#      'wqwateraccess',
#      'totalbathroomsedited',
#      'totallivingarea',
#      'parcel_area',
#      'distance_park',
#      'distance_nyc',
#      'distance_golf',
#      'shorelinedistancedv3_1000',
#      'shorelinedistancedv1000_2000',
#      'shorelinedistancedv2000_3000',
#      'wqshorelinedistancedv3_1000',
#      'wqshorelinedistancedv1000_2000',
#      'wqshorelinedistancedv2000_3000',
#      'education',
#      'income_real-2015',
#      'povertylevel',
#      'pct_white',
#      'dv_2002',
#      'dv_2003',
#      'dv_2004',
#      'dv_2005',
#      'dv_2006',
#      'dv_2007',
#      'dv_2008',
#      'dv_2009',
#      'dv_2010',
#      'dv_2011',
#      'dv_2012',
#      'dv_2013',
#      'dv_2014',
#      'dv_2015'],
#     'yvar': 'saleprice_real-2015',
#     'transform': {'ln_wq': 1, 'ln_y': 1},
#     'wt_type': 'NN',
#     'NNscope': 'year',
#     'distmat': 1},
#    'results': <spreg.ml_error.ML_Error at 0x7f8056598898>},
#   {'modeldict': {'combine_pre_post': 0,
#     'period': 1,
#     'modeltype': 'SEM',
#     'klist': 20,
#     'xvars': ['secchi',
#      'bayfront',
#      'wateraccess',
#      'wqbayfront',
#      'wqwateraccess',
#      'totalbathroomsedited',
#      'totallivingarea',
#      'parcel_area',
#      'distance_park',
#      'distance_nyc',
#      'distance_golf',
#      'shorelinedistancedv3_1000',
#      'shorelinedistancedv1000_2000',
#      'shorelinedistancedv2000_3000',
#      'wqshorelinedistancedv3_1000',
#      'wqshorelinedistancedv1000_2000',
#      'wqshorelinedistancedv2000_3000',
#      'education',
#      'income_real-2015',
#      'povertylevel',
#      'pct_white',
#      'dv_2002',
#      'dv_2003',
#      'dv_2004',
#      'dv_2005',
#      'dv_2006',
#      'dv_2007',
#      'dv_2008',
#      'dv_2009',
#      'dv_2010',
#      'dv_2011',
#      'dv_2012',
#      'dv_2013',
#      'dv_2014',
#      'dv_2015'],
#     'yvar': 'saleprice_real-2015',
#     'transform': {'ln_wq': 1, 'ln_y': 1},
#     'wt_type': 'NN',
#     'NNscope': 'year',
#     'distmat': 1},
#    'results': <spreg.ml_error.ML_Error at 0x7f8056598b38>},
#   {'modeldict': {'combine_pre_post': 0,
#     'period': 1,
#     'modeltype': 'SEM',
#     'klist': 25,
#     'xvars': ['secchi',
#      'bayfront',
#      'wateraccess',
#      'wqbayfront',
#      'wqwateraccess',
#      'totalbathroomsedited',
#      'totallivingarea',
#      'parcel_area',
#      'distance_park',
#      'distance_nyc',
#      'distance_golf',
#      'shorelinedistancedv3_1000',
#      'shorelinedistancedv1000_2000',
#      'shorelinedistancedv2000_3000',
#      'wqshorelinedistancedv3_1000',
#      'wqshorelinedistancedv1000_2000',
#      'wqshorelinedistancedv2000_3000',
#      'education',
#      'income_real-2015',
#      'povertylevel',
#      'pct_white',
#      'dv_2002',
#      'dv_2003',
#      'dv_2004',
#      'dv_2005',
#      'dv_2006',
#      'dv_2007',
#      'dv_2008',
#      'dv_2009',
#      'dv_2010',
#      'dv_2011',
#      'dv_2012',
#      'dv_2013',
#      'dv_2014',
#      'dv_2015'],
#     'yvar': 'saleprice_real-2015',
#     'transform': {'ln_wq': 1, 'ln_y': 1},
#     'wt_type': 'NN',
#     'NNscope': 'year',
#     'distmat': 1},
#    'results': <spreg.ml_error.ML_Error at 0x7f8056598dd8>},
#   {'modeldict': {'combine_pre_post': 0,
#     'period': 1,
#     'modeltype': 'SEM',
#     'klist': 50,
#     'xvars': ['secchi',
#      'bayfront',
#      'wateraccess',
#      'wqbayfront',
#      'wqwateraccess',
#      'totalbathroomsedited',
#      'totallivingarea',
#      'parcel_area',
#      'distance_park',
#      'distance_nyc',
#      'distance_golf',
#      'shorelinedistancedv3_1000',
#      'shorelinedistancedv1000_2000',
#      'shorelinedistancedv2000_3000',
#      'wqshorelinedistancedv3_1000',
#      'wqshorelinedistancedv1000_2000',
#      'wqshorelinedistancedv2000_3000',
#      'education',
#      'income_real-2015',
#      'povertylevel',
#      'pct_white',
#      'dv_2002',
#      'dv_2003',
#      'dv_2004',
#      'dv_2005',
#      'dv_2006',
#      'dv_2007',
#      'dv_2008',
#      'dv_2009',
#      'dv_2010',
#      'dv_2011',
#      'dv_2012',
#      'dv_2013',
#      'dv_2014',
#      'dv_2015'],
#     'yvar': 'saleprice_real-2015',
#     'transform': {'ln_wq': 1, 'ln_y': 1},
#     'wt_type': 'NN',
#     'NNscope': 'year',
#     'distmat': 1},
#    'results': <spreg.ml_error.ML_Error at 0x7f80565240b8>},
#   {'modeldict': {'combine_pre_post': 0,
#     'period': 1,
#     'modeltype': 'SEM',
#     'klist': 100,
#     'xvars': ['secchi',
#      'bayfront',
#      'wateraccess',
#      'wqbayfront',
#      'wqwateraccess',
#      'totalbathroomsedited',
#      'totallivingarea',
#      'parcel_area',
#      'distance_park',
#      'distance_nyc',
#      'distance_golf',
#      'shorelinedistancedv3_1000',
#      'shorelinedistancedv1000_2000',
#      'shorelinedistancedv2000_3000',
#      'wqshorelinedistancedv3_1000',
#      'wqshorelinedistancedv1000_2000',
#      'wqshorelinedistancedv2000_3000',
#      'education',
#      'income_real-2015',
#      'povertylevel',
#      'pct_white',
#      'dv_2002',
#      'dv_2003',
#      'dv_2004',
#      'dv_2005',
#      'dv_2006',
#      'dv_2007',
#      'dv_2008',
#      'dv_2009',
#      'dv_2010',
#      'dv_2011',
#      'dv_2012',
#      'dv_2013',
#      'dv_2014',
#      'dv_2015'],
#     'yvar': 'saleprice_real-2015',
#     'transform': {'ln_wq': 1, 'ln_y': 1},
#     'wt_type': 'NN',
#     'NNscope': 'year',
#     'distmat': 1},
#    'results': <spreg.ml_error.ML_Error at 0x7f8056524358>}]]

# %%
idata_obj.printSEMResults()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~/gits/island/island.py in printSEMResults(self)
#     175         try:
# --> 176             assert self.resultsDFdictlist,"building resultsDFdictlist"
#     177         except:
#
# AssertionError: building resultsDFdictlist
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-0ae23d78bebf> in <module>
# ----> 1 idata_obj.printSEMResults()
#
# ~/gits/island/island.py in printSEMResults(self)
#     176             assert self.resultsDFdictlist,"building resultsDFdictlist"
#     177         except:
# --> 178             self.doSEMResultsToDF()
#     179         resultsDFdictlist=self.resultsDFdictlist
#     180         modeltablehtml='SEM Results'
#
# ~/gits/island/island.py in doSEMResultsToDF(self)
#     156
#     157         for resultsdict in resultsdictlist:
# --> 158             modeldict=resultsdict['modeldict']
#     159             semresult=resultsdict['results']
#     160
#
# TypeError: list indices must be integers or slices, not str
