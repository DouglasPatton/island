# %% [markdown]
# ## Long Island Hedonic Analysis - Draft
# ### Visualizing the data
# #### created by Doug Patton
# <br>
# If you run the notebook with matplotlib widgets turned on (and installed), you can rotate and zoom in on the 3d plots.

# %%
import island

# %%
import numpy as np
import pandas as pd

# %%
#from importlib import reload  
#reload(island)

# %%
# %matplotlib inline
#may be necessary to display plots inline on some systems
#%pylab #interactive graphs in external window
#%matplotlib widget #makes graphs interactive inline

# %%
idata_obj=island.IslandData()

# %%
#idata_obj.getDataFromCSV() # run once

# %%
#idata_obj.doCSVToDict() # run once

# %%
idata_obj.makeTimeListArrayList()

# %%
#create new real version for each dollar variable using the CPI
baseyear=2015
idata_obj.addRealByCPI(to_year=baseyear)

# %%
idata_obj.arrayListToPandasDF()

# %%
dfi=idata_obj.df.loc[0]

# %%
dfi.loc[:]['sale_year']
# Out:
# sale_year  idx
# 2002       0       2002
#            1       2002
#            2       2002
#            3       2002
#            4       2002
#                    ...
# 2012       1483    2012
#            1484    2012
#            1485    2012
#            1486    2012
#            1487    2012
# Name: sale_year, Length: 23174, dtype: uint16

# %%
idata_obj.printDFtoSumStats()

# %%
idata_obj.df.loc[1].describe()
# Out:
#         sale_year    saleprice  assessedvalue  postsandy       secchi  \
# count  8799.00000  8799.000000    8799.000000     8799.0  8799.000000
# mean   2014.19434    -0.104144      -0.034202        1.0     1.487954
# std       0.90273     1.052227       0.893081        0.0     0.467630
# min    2012.00000    -2.195929      -1.736039        1.0     1.000000
# 25%    2013.00000    -0.671436      -0.571272        1.0     1.083333
# 50%    2014.00000    -0.313013      -0.237372        1.0     1.416667
# 75%    2015.00000     0.188780       0.231123        1.0     1.700000
# max    2015.00000    11.658323       9.518195        1.0     3.500000
#
#         wqbayfront  wqwateraccess  wqwaterhouse  totalbathroomsedited  \
# count  8799.000000    8799.000000   8799.000000           8799.000000
# mean      0.009104       0.055622      0.064725              1.962609
# std       0.124990       0.315432      0.337797              0.823556
# min       0.000000       0.000000      0.000000              1.000000
# 25%       0.000000       0.000000      0.000000              1.500000
# 50%       0.000000       0.000000      0.000000              2.000000
# 75%       0.000000       0.000000      0.000000              2.500000
# max       2.603540       2.593171      2.603540              8.000000
#
#        totallivingarea  ...  shorelinedistancedv2000_3000  \
# count      8799.000000  ...                   8799.000000
# mean          0.024356  ...                      0.171042
# std           0.998418  ...                      0.376567
# min          -1.916701  ...                      0.000000
# 25%          -0.635287  ...                      0.000000
# 50%          -0.177157  ...                      0.000000
# 75%           0.441318  ...                      0.000000
# max          13.721681  ...                      1.000000
#
#        shorelinedistancedv3000_4000  soldmorethanonceinyear  \
# count                   8799.000000             8799.000000
# mean                       0.143880                0.023525
# std                        0.350988                0.151574
# min                        0.000000                0.000000
# 25%                        0.000000                0.000000
# 50%                        0.000000                0.000000
# 75%                        0.000000                0.000000
# max                        1.000000                1.000000
#
#        soldmorethanonceovertheyears     latitude    longitude  \
# count                   8799.000000  8799.000000  8799.000000
# mean                       0.481646    40.653981   -73.622144
# std                        0.499691     0.026579     0.072169
# min                        0.000000    40.584320   -73.755870
# 25%                        0.000000    40.640310   -73.683365
# 50%                        0.000000    40.657670   -73.629050
# 75%                        1.000000    40.673695   -73.556910
# max                        1.000000    40.701170   -73.482940
#
#        saleprice_real-2015  assessedvalue_real-2015  income_real-2015  \
# count          8799.000000              8799.000000       8799.000000
# mean             -0.325241                -0.276298          0.122858
# std               0.925551                 0.781644          1.050166
# min              -2.167902                -1.757304         -2.575421
# 25%              -0.829777                -0.745542         -0.567862
# 50%              -0.510178                -0.452368          0.016444
# 75%              -0.075444                -0.041247          0.664259
# max               9.988481                 8.196839          4.242513
#
#                idx
# count  8799.000000
# mean   1623.364132
# std    1125.967392
# min       0.000000
# 25%     733.000000
# 50%    1466.000000
# 75%    2155.500000
# max    4355.000000
#
# [8 rows x 41 columns]

# %%
test=idata_obj.df.loc[0]["secchi"].describe()
test
# Out:
# count    23174.000000
# mean         1.832745
# std          0.455897
# min          0.601854
# 25%          1.481468
# 50%          1.836880
# 75%          2.132101
# max          4.109069
# Name: secchi, dtype: float64

# %%
idata_obj.df[:]['sale_year'].describe()
# Out:
# count    31973.000000
# mean      2008.680731
# std          4.175116
# min       2002.000000
# 25%       2005.000000
# 50%       2008.000000
# 75%       2013.000000
# max       2015.000000
# Name: sale_year, dtype: float64

# %%
idata_obj.df.index
# Out:
# MultiIndex([(0, 2002,    0),
#             (0, 2002,    1),
#             (0, 2002,    2),
#             (0, 2002,    3),
#             (0, 2002,    4),
#             (0, 2002,    5),
#             (0, 2002,    6),
#             (0, 2002,    7),
#             (0, 2002,    8),
#             (0, 2002,    9),
#             ...
#             (1, 2015, 4346),
#             (1, 2015, 4347),
#             (1, 2015, 4348),
#             (1, 2015, 4349),
#             (1, 2015, 4350),
#             (1, 2015, 4351),
#             (1, 2015, 4352),
#             (1, 2015, 4353),
#             (1, 2015, 4354),
#             (1, 2015, 4355)],
#            names=['postsandy', 'sale_year', 'idx'], length=31973)

# %%
idata_obj.df.loc[0]['sale_year'].astype(np.float64).mean()
# Out:
# 2006.5872529558987

# %%
idata_obj.df.astype({'sale_year':np.int32,'saleprice':'int32','assessedvalue':'int32','wateraccess':np.int32},copy=False)
# Out:
#                           sale_year  saleprice  assessedvalue  postsandy  \
# postsandy sale_year idx
# 0         2002      0          2002          0              0          0
#                     1          2002          0              2          0
#                     2          2002          0              0          0
#                     3          2002         -1              0          0
#                     4          2002         -1             -1          0
# ...                             ...        ...            ...        ...
# 1         2015      4351       2015          0              0          1
#                     4352       2015          0              0          1
#                     4353       2015          0              0          1
#                     4354       2015          0              0          1
#                     4355       2015          0              0          1
#
#                             secchi  wqbayfront  wqwateraccess  wqwaterhouse  \
#                     4355            -0.245463                -0.738792
#
#                           income_real-2015   idx
# postsandy sale_year idx
# 0         2002      0             0.733757     0
#                     1             2.769243     1
#                     2            -1.520684     2
#                     3             0.111501     3
#                     4            -1.080175     4
# ...                                    ...   ...
# 1         2015      4351          0.598556  4351
#                     4352          0.598556  4352
#                     4353          0.598556  4353
#                     4354          0.598556  4354
#                     4355          0.598556  4355
#
# [31973 rows x 41 columns]

# %%
import joblib

# %%
thehash=joblib.hash(idata_obj.df.to_csv().encode('utf-8'))

# %%
thehash
# Out:
# '6ad2f4b745047b3b22d2c6fa7eb061dc'

# %%
thehash2=joblib.hash(idata_obj.df.to_csv().encode('utf-8'))
thehash2
# Out:
# '6ad2f4b745047b3b22d2c6fa7eb061dc'

# %%
idata_obj.df.columns
# Out:
# Index(['sale_year', 'saleprice', 'assessedvalue', 'postsandy', 'secchi',
#        'wqbayfront', 'wqwateraccess', 'wqwaterhouse', 'totalbathroomsedited',
#        'totallivingarea', 'saleacres', 'distance_park', 'distance_nyc',
#        'distance_golf', 'wqshorelinedistancedv3_1000',
#        'wqshorelinedistancedv1000_2000', 'wqshorelinedistancedv2000_3000',
#        'wqshorelinedistancedv3000_4000', 'education', 'income', 'povertylevel',
#        'pct_white', 'pct_asian', 'pct_black', 'bayfront', 'wateraccess',
#        'waterhouse', 'shorelinedistance', 'distance_shoreline',
#        'shorelinedistancedv3_1000', 'shorelinedistancedv1000_2000',
#        'shorelinedistancedv2000_3000', 'shorelinedistancedv3000_4000',
#        'soldmorethanonceinyear', 'soldmorethanonceovertheyears', 'latitude',
#        'longitude', 'saleprice_real-2015', 'assessedvalue_real-2015',
#        'income_real-2015', 'idx'],
#       dtype='object')

# %%
test=idata_obj.df.loc['0']['secchi'].astype(np.float64).describe(include='all')
type(test)
test.to_json()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: '0'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-4be0ea1b6728> in <module>
# ----> 1 test=idata_obj.df.loc['0']['secchi'].astype(np.float64).describe(include='all')
#       2 type(test)
#       3 test.to_json()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1765
#    1766             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1767             return self._getitem_axis(maybe_callable, axis=axis)
#    1768
#    1769     def _is_scalar_access(self, key: Tuple):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1962         # fall thru to straight lookup
#    1963         self._validate_key(key, axis)
# -> 1964         return self._get_label(key, axis=axis)
#    1965
#    1966
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#     622             raise IndexingError("no slices here, handle elsewhere")
#     623
# --> 624         return self.obj._xs(label, axis=axis)
#     625
#     626     def _get_loc(self, key: int, axis: int):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3533         index = self.index
#    3534         if isinstance(index, MultiIndex):
# -> 3535             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3536         else:
#    3537             loc = self.index.get_loc(key)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/multi.py in get_loc_level(self, key, level, drop_level)
#    2844                 return indexer, maybe_mi_droplevels(indexer, ilevels, drop_level)
#    2845         else:
# -> 2846             indexer = self._get_level_indexer(key, level=level)
#    2847             return indexer, maybe_mi_droplevels(indexer, [level], drop_level)
#    2848
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/multi.py in _get_level_indexer(self, key, level, indexer)
#    2927         else:
#    2928
# -> 2929             code = self._get_loc_single_level_index(level_index, key)
#    2930
#    2931             if level > 0 or self.lexsort_depth == 0:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/multi.py in _get_loc_single_level_index(self, level_index, key)
#    2596             return -1
#    2597         else:
# -> 2598             return level_index.get_loc(key)
#    2599
#    2600     def get_loc(self, key, method=None):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: '0'

# %%
test=idata_obj.df.describe(include='all').to_html()
with open('test.html', 'w') as f:
    f.write(test)

# %%
idata_obj.df.head(100)

# %%
(idata_obj.df.columns)

# %%
idata_obj.df.loc[1][:]['sale_year'].mean()

# %%
idata_obj.df.apply(idata_obj.printdfcol,axis=0)

# %%
idata_obj.df.iloc[:,1].mean()
# Out:
# 2.6757530435348215e-16

# %%
idata_obj.df.describe()
# Out:
#           sale_year     saleprice  assessedvalue     postsandy        secchi  \
# count  31973.000000  3.197300e+04   3.197300e+04  31973.000000  31973.000000
# mean    2008.680731  2.675753e-16   1.441349e-16      0.275201      1.737858
# std        4.175116  1.000000e+00   1.000000e+00      0.446622      0.484284
# min     2002.000000 -2.195929e+00  -2.302892e+00      0.000000      0.601854
# 25%     2005.000000 -5.519616e-01  -5.712722e-01      0.000000      1.333333
# 50%     2008.000000 -1.995121e-01  -2.321957e-01      0.000000      1.708333
# 75%     2013.000000  3.082541e-01   2.647714e-01      1.000000      2.000535
# max     2015.000000  1.452571e+01   2.458769e+01      1.000000      4.109069
#
#          wqbayfront  wqwateraccess  wqwaterhouse  totalbathroomsedited  \
# count  31973.000000   31973.000000  31973.000000          31973.000000
# mean       0.009307       0.061502      0.070810              1.953273
# std        0.139272       0.343761      0.369356              0.834382
# min        0.000000       0.000000      0.000000              1.000000
# 25%        0.000000       0.000000      0.000000              1.000000
# 50%        0.000000       0.000000      0.000000              2.000000
# 75%        0.000000       0.000000      0.000000              2.500000
# max        3.708014       3.347050      3.708014             13.000000
#
#        totallivingarea  ...  shorelinedistancedv2000_3000  \
# count     3.197300e+04  ...                  31973.000000
# mean     -1.200262e-16  ...                      0.177243
# std       1.000000e+00  ...                      0.381880
# min      -1.938260e+00  ...                      0.000000
# 25%      -6.554981e-01  ...                      0.000000
# 50%      -2.135380e-01  ...                      0.000000
# 75%       4.022418e-01  ...                      0.000000
# max       1.463659e+01  ...                      1.000000
#
#        shorelinedistancedv3000_4000  soldmorethanonceinyear  \
# count                  31973.000000            31973.000000
# mean                       0.148375                0.018078
# std                        0.355477                0.133235
# min                        0.000000                0.000000
# 25%                        0.000000                0.000000
# 50%                        0.000000                0.000000
# 75%                        0.000000                0.000000
# max                        1.000000                1.000000
#
#        soldmorethanonceovertheyears      latitude     longitude  \
# count                  31973.000000  31973.000000  31973.000000
# mean                       0.522628     40.653100    -73.630145
# std                        0.499496      0.026857      0.068841
# min                        0.000000     40.584180    -73.758930
# 25%                        0.000000     40.638180    -73.688800
# 50%                        1.000000     40.657090    -73.634690
# 75%                        1.000000     40.673550    -73.581900
# max                        1.000000     40.701170    -73.482440
#
#        saleprice_real-2015  assessedvalue_real-2015  income_real-2015  \
# count         3.197300e+04             3.197300e+04      3.197300e+04
# mean          8.187750e-14             1.279890e-14      8.400766e-14
# std           1.000000e+00             1.000000e+00      1.000000e+00
# min          -2.167902e+00            -2.244990e+00     -2.753381e+00
# 25%          -5.786401e-01            -5.810021e-01     -7.070585e-01
# 50%          -1.948166e-01            -2.282370e-01     -1.341218e-01
# 75%           3.134812e-01             2.649748e-01      5.697193e-01
# max           1.376174e+01             2.523595e+01      4.867828e+00
#
#                 idx
# count  31973.000000
# mean    1368.487130
# std      980.152834
# min        0.000000
# 25%      591.000000
# 50%     1206.000000
# 75%     1931.000000
# max     4355.000000
#
# [8 rows x 41 columns]
